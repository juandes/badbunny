# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from fbprophet import Prophet

# %%
sns.set()
plt.rc('xtick', labelsize=16)
plt.rc('ytick', labelsize=16)
plt.rc('axes', labelsize=14)

# %%
df = pd.read_csv('data/timeseries_date.csv')

# %%
m = Prophet()

# %%
m.fit(df)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Initial log joint probability = -8.06742
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       3440.39   0.000141112       81.6381      0.2921      0.2921      125
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       3441.13   0.000889918       76.9992           1           1      245
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      204       3441.15   0.000180065       71.7264   2.651e-06       0.001      286  LS failed, Hessian reset
#      299        3441.5    0.00465997       103.485           1           1      406
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      313       3441.88   0.000249392       88.5479   1.253e-06       0.001      468  LS failed, Hessian reset
#      364       3442.09    2.2213e-07       67.1212      0.2444           1      535
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance

# %%
forecast = m.predict(df)

# %%
fig = m.plot_components(forecast)
fig.set_size_inches(18.5, 10.5)
fig.set_dpi(150)
